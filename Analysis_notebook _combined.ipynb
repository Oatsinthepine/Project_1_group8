# %% [markdown]
# # Project_1: How does the loan impact the customer demographics based on personal parameters?

# %% [markdown]
# * Loan_dataset EDA

# %%
#import all required dependencies for this EDA project:

import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
# accessing the csv file path and read the data:
file_path_1 = Path("data/LoanDataset - LoansDatasest.csv") 
loan_df = pd.read_csv(file_path_1)

# %%
# checking the df:
loan_df.head()
# Out:
#    customer_id  customer_age customer_income home_ownership  \
# 0          1.0            22           59000           RENT
# 1          2.0            21            9600            OWN
# 2          3.0            25            9600       MORTGAGE
# 3          4.0            23           65500           RENT
# 4          5.0            24           54400           RENT
#
#    employment_duration loan_intent loan_grade   loan_amnt  loan_int_rate  \
# 0                123.0    PERSONAL          C  £35,000.00          16.02
# 1                  5.0   EDUCATION          A   £1,000.00          11.14
# 2                  1.0     MEDICAL          B   £5,500.00          12.87
# 3                  4.0     MEDICAL          B  £35,000.00          15.23
# 4                  8.0     MEDICAL          B  £35,000.00          14.27
#
#    term_years historical_default  cred_hist_length Current_loan_status
# 0          10                  Y                 3             DEFAULT
# 1           1                NaN                 2          NO DEFAULT
# 2           5                  N                 3             DEFAULT
# 3          10                  N                 2             DEFAULT
# 4          10                  Y                 4             DEFAULT

# %%
loan_df.describe() # we can see some columns dtypes need to be changed.
# Out:
#         customer_id  customer_age  employment_duration  loan_int_rate  \
# count  32583.000000  32586.000000         31691.000000   29470.000000
# mean   16289.497806     27.732769             4.790161      11.011553
# std     9405.919628      6.360528             4.142746       3.240440
# min        1.000000      3.000000             0.000000       5.420000
# 25%     8144.500000     23.000000             2.000000       7.900000
# 50%    16288.000000     26.000000             4.000000      10.990000
# 75%    24433.500000     30.000000             7.000000      13.470000
# max    32581.000000    144.000000           123.000000      23.220000
#
#          term_years  cred_hist_length
# count  32586.000000      32586.000000
# mean       4.761738          5.804026
# std        2.471107          4.055078
# min        1.000000          2.000000
# 25%        3.000000          3.000000
# 50%        4.000000          4.000000
# 75%        7.000000          8.000000
# max       10.000000         30.000000

# %%
loan_df.info #checking
# Out:
# <bound method DataFrame.info of        customer_id  customer_age customer_income home_ownership  \
# 0              1.0            22           59000           RENT
# 1              2.0            21            9600            OWN
# 2              3.0            25            9600       MORTGAGE
# 3              4.0            23           65500           RENT
# 4              5.0            24           54400           RENT
# ...            ...           ...             ...            ...
# 32581      32577.0            57           53000       MORTGAGE
# 32582      32578.0            54          120000       MORTGAGE
# 32583      32579.0            65           76000           RENT
# 32584      32580.0            56          150000       MORTGAGE
# 32585      32581.0            99           42000           RENT
#
#        employment_duration      loan_intent loan_grade   loan_amnt  \
# 0                    123.0         PERSONAL          C  £35,000.00
# 1                      5.0        EDUCATION          A   £1,000.00
# 2                      1.0          MEDICAL          B   £5,500.00
# 3                      4.0          MEDICAL          B  £35,000.00
# 4                      8.0          MEDICAL          B  £35,000.00
# ...                    ...              ...        ...         ...
# 32581                  1.0         PERSONAL          C   £5,800.00
# 32582                  4.0         PERSONAL          A  £17,625.00
# 32583                  3.0  HOMEIMPROVEMENT          B  £35,000.00
# 32584                  5.0         PERSONAL          B  £15,000.00
# 32585                  2.0          MEDICAL          B   £6,475.00
#
#        loan_int_rate  term_years historical_default  cred_hist_length  \
# 0              16.02          10                  Y                 3
# 1              11.14           1                NaN                 2
# 2              12.87           5                  N                 3
# 3              15.23          10                  N                 2
# 4              14.27          10                  Y                 4
# ...              ...         ...                ...               ...
# 32581          13.16           7                NaN                30
# 32582           7.49           4                NaN                19
# 32583          10.99           5                  N                28
# 32584          11.48           6                NaN                26
# 32585           9.99           6                NaN                30
#
#       Current_loan_status
# 0                 DEFAULT
# 1              NO DEFAULT
# 2                 DEFAULT
# 3                 DEFAULT
# 4                 DEFAULT
# ...                   ...
# 32581          NO DEFAULT
# 32582          NO DEFAULT
# 32583             DEFAULT
# 32584          NO DEFAULT
# 32585          NO DEFAULT
#
# [32586 rows x 13 columns]>

# %%
loan_df.dtypes # need to change dtypes later.
# Out:
# customer_id            float64
# customer_age             int64
# customer_income         object
# home_ownership          object
# employment_duration    float64
# loan_intent             object
# loan_grade              object
# loan_amnt               object
# loan_int_rate          float64
# term_years               int64
# historical_default      object
# cred_hist_length         int64
# Current_loan_status     object
# dtype: object

# %%
#check all the NaN 
loan_df.isna().sum() # need to drop NA later.
# Out:
# customer_id                3
# customer_age               0
# customer_income            0
# home_ownership             0
# employment_duration      895
# loan_intent                0
# loan_grade                 0
# loan_amnt                  1
# loan_int_rate           3116
# term_years                 0
# historical_default     20737
# cred_hist_length           0
# Current_loan_status        4
# dtype: int64

# %%
# check for duplication:
loan_df.loc[loan_df.duplicated()] # need to get rid of duplicated roles.
# Out:
#        customer_id  customer_age customer_income home_ownership  \
# 323          323.0            25          120000           RENT
# 325          324.0            23          120000           RENT
# 14691      14688.0            21           32000           RENT
# 14692      14689.0            22           38000           RENT
# 30289      30284.0            47           70000           RENT
# 30290      30285.0            44           70000           RENT
#
#        employment_duration        loan_intent loan_grade      loan_amnt  \
# 323                    6.0            MEDICAL          A  £1,000,000.00
# 325                    7.0          EDUCATION          A     £25,000.00
# 14691                  6.0           PERSONAL          B     £15,000.00
# 14692                  6.0           PERSONAL          A     £15,000.00
# 30289                  3.0    HOMEIMPROVEMENT          A      £6,000.00
# 30290                 15.0  DEBTCONSOLIDATION          A      £6,000.00
#
#        loan_int_rate  term_years historical_default  cred_hist_length  \
# 323            10.74          10                  N                 2
# 325             9.99          10                NaN                 2
# 14691          15.27           1                  Y                 3
# 14692           7.88           2                  N                 3
# 30289           8.49           7                  N                12
# 30290           5.79           4                  N                16
#
#       Current_loan_status
# 323               DEFAULT
# 325            NO DEFAULT
# 14691             DEFAULT
# 14692             DEFAULT
# 30289          NO DEFAULT
# 30290             DEFAULT

# %%
loan_df_test = loan_df.copy() #here making a copy of the original df.
loan_df_test = loan_df_test.drop_duplicates() # drop the duplicates on the copied df.

# %%
loan_df_test.columns
# Out:
# Index(['customer_id', 'customer_age', 'customer_income', 'home_ownership',
#        'employment_duration', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'term_years', 'historical_default', 'cred_hist_length',
#        'Current_loan_status'],
#       dtype='object')

# %%
#tidy up the loan_df_test and subsetting df that contains wanted columns:
tidy_loan_df = loan_df_test[['customer_age', 'customer_income', 'home_ownership',
       'employment_duration', 'loan_intent', 'loan_grade', 'loan_amnt',
       'loan_int_rate', 'term_years','historical_default', 'cred_hist_length',
       'Current_loan_status']]
tidy_loan_df
# Out:
#        customer_age customer_income home_ownership  employment_duration  \
# 0                22           59000           RENT                123.0
# 1                21            9600            OWN                  5.0
# 2                25            9600       MORTGAGE                  1.0
# 3                23           65500           RENT                  4.0
# 4                24           54400           RENT                  8.0
# ...             ...             ...            ...                  ...
# 32581            57           53000       MORTGAGE                  1.0
# 32582            54          120000       MORTGAGE                  4.0
# 32583            65           76000           RENT                  3.0
# 32584            56          150000       MORTGAGE                  5.0
# 32585            99           42000           RENT                  2.0
#
#            loan_intent loan_grade   loan_amnt  loan_int_rate  term_years  \
# 0             PERSONAL          C  £35,000.00          16.02          10
# 1            EDUCATION          A   £1,000.00          11.14           1
# 2              MEDICAL          B   £5,500.00          12.87           5
# 3              MEDICAL          B  £35,000.00          15.23          10
# 4              MEDICAL          B  £35,000.00          14.27          10
# ...                ...        ...         ...            ...         ...
# 32581         PERSONAL          C   £5,800.00          13.16           7
# 32582         PERSONAL          A  £17,625.00           7.49           4
# 32583  HOMEIMPROVEMENT          B  £35,000.00          10.99           5
# 32584         PERSONAL          B  £15,000.00          11.48           6
# 32585          MEDICAL          B   £6,475.00           9.99           6
#
#       historical_default  cred_hist_length Current_loan_status
# 0                      Y                 3             DEFAULT
# 1                    NaN                 2          NO DEFAULT
# 2                      N                 3             DEFAULT
# 3                      N                 2             DEFAULT
# 4                      Y                 4             DEFAULT
# ...                  ...               ...                 ...
# 32581                NaN                30          NO DEFAULT
# 32582                NaN                19          NO DEFAULT
# 32583                  N                28             DEFAULT
# 32584                NaN                26          NO DEFAULT
# 32585                NaN                30          NO DEFAULT
#
# [32580 rows x 12 columns]

# %%
# same here make the copy of tidy loan df and drop NA.
test_copy = tidy_loan_df.copy()
test_copy = test_copy.dropna(how = 'all')

# %%
test_copy.shape
# Out:
# (32580, 12)

# %%
test_copy = test_copy.reset_index(drop=True).copy() #reseting the index to make it more readable.
test_copy
# Out:
#        customer_age customer_income home_ownership  employment_duration  \
# 0                22           59000           RENT                123.0
# 1                21            9600            OWN                  5.0
# 2                25            9600       MORTGAGE                  1.0
# 3                23           65500           RENT                  4.0
# 4                24           54400           RENT                  8.0
# ...             ...             ...            ...                  ...
# 32575            57           53000       MORTGAGE                  1.0
# 32576            54          120000       MORTGAGE                  4.0
# 32577            65           76000           RENT                  3.0
# 32578            56          150000       MORTGAGE                  5.0
# 32579            99           42000           RENT                  2.0
#
#            loan_intent loan_grade   loan_amnt  loan_int_rate  term_years  \
# 0             PERSONAL          C  £35,000.00          16.02          10
# 1            EDUCATION          A   £1,000.00          11.14           1
# 2              MEDICAL          B   £5,500.00          12.87           5
# 3              MEDICAL          B  £35,000.00          15.23          10
# 4              MEDICAL          B  £35,000.00          14.27          10
# ...                ...        ...         ...            ...         ...
# 32575         PERSONAL          C   £5,800.00          13.16           7
# 32576         PERSONAL          A  £17,625.00           7.49           4
# 32577  HOMEIMPROVEMENT          B  £35,000.00          10.99           5
# 32578         PERSONAL          B  £15,000.00          11.48           6
# 32579          MEDICAL          B   £6,475.00           9.99           6
#
#       historical_default  cred_hist_length Current_loan_status
# 0                      Y                 3             DEFAULT
# 1                    NaN                 2          NO DEFAULT
# 2                      N                 3             DEFAULT
# 3                      N                 2             DEFAULT
# 4                      Y                 4             DEFAULT
# ...                  ...               ...                 ...
# 32575                NaN                30          NO DEFAULT
# 32576                NaN                19          NO DEFAULT
# 32577                  N                28             DEFAULT
# 32578                NaN                26          NO DEFAULT
# 32579                NaN                30          NO DEFAULT
#
# [32580 rows x 12 columns]

# %%
# convert dtypes:
test_copy['customer_income'] = test_copy['customer_income'].astype(str)
test_copy['customer_income'] = test_copy['customer_income'].str.strip()
test_copy['customer_income'] = test_copy['customer_income'].str.replace(',', '', regex=False)
test_copy['customer_income'] = pd.to_numeric(test_copy['customer_income']) # convert customer income column data to numeric for later calculation.

test_copy = test_copy.rename(columns={'loan_amnt':'loan_amnt(pounds)'})

test_copy['loan_amnt(pounds)'] = test_copy['loan_amnt(pounds)'].astype(str)
test_copy['loan_amnt(pounds)'] = test_copy['loan_amnt(pounds)'].str.strip()
test_copy['loan_amnt(pounds)'] = test_copy['loan_amnt(pounds)'].str.replace('£', '', regex=False)
test_copy['loan_amnt(pounds)'] = test_copy['loan_amnt(pounds)'].str.replace(',', '', regex=False)

test_copy['loan_amnt(pounds)'] = pd.to_numeric(test_copy['loan_amnt(pounds)'], errors='coerce') # Force remove any string that cannot be parsed.
test_copy['loan_amnt(pounds)'] = test_copy['loan_amnt(pounds)'].fillna(0) # filling NaN value using 0

cleaned_loan_df = test_copy

cleaned_loan_df # this is the variable completed cleasing of the loan data, use this variable for all questions below.
# Out:
#        customer_age  customer_income home_ownership  employment_duration  \
# 0                22            59000           RENT                123.0
# 1                21             9600            OWN                  5.0
# 2                25             9600       MORTGAGE                  1.0
# 3                23            65500           RENT                  4.0
# 4                24            54400           RENT                  8.0
# ...             ...              ...            ...                  ...
# 32575            57            53000       MORTGAGE                  1.0
# 32576            54           120000       MORTGAGE                  4.0
# 32577            65            76000           RENT                  3.0
# 32578            56           150000       MORTGAGE                  5.0
# 32579            99            42000           RENT                  2.0
#
#            loan_intent loan_grade  loan_amnt(pounds)  loan_int_rate  \
# 0             PERSONAL          C            35000.0          16.02
# 1            EDUCATION          A             1000.0          11.14
# 2              MEDICAL          B             5500.0          12.87
# 3              MEDICAL          B            35000.0          15.23
# 4              MEDICAL          B            35000.0          14.27
# ...                ...        ...                ...            ...
# 32575         PERSONAL          C             5800.0          13.16
# 32576         PERSONAL          A            17625.0           7.49
# 32577  HOMEIMPROVEMENT          B            35000.0          10.99
# 32578         PERSONAL          B            15000.0          11.48
# 32579          MEDICAL          B             6475.0           9.99
#
#        term_years historical_default  cred_hist_length Current_loan_status
# 0              10                  Y                 3             DEFAULT
# 1               1                NaN                 2          NO DEFAULT
# 2               5                  N                 3             DEFAULT
# 3              10                  N                 2             DEFAULT
# 4              10                  Y                 4             DEFAULT
# ...           ...                ...               ...                 ...
# 32575           7                NaN                30          NO DEFAULT
# 32576           4                NaN                19          NO DEFAULT
# 32577           5                  N                28             DEFAULT
# 32578           6                NaN                26          NO DEFAULT
# 32579           6                NaN                30          NO DEFAULT
#
# [32580 rows x 12 columns]

# %% [markdown]
# # Analysis part:

# %% [markdown]
# # Wang Han (Sher)'s part:
#
# ## Question 4: Is there any relationship between term of years and loan status?

# %%
cleaned_loan_df_new = cleaned_loan_df.dropna() #further cleanning.
cleaned_loan_df_new
# Out:
#        customer_age  customer_income home_ownership  employment_duration  \
# 0                22            59000           RENT                123.0
# 2                25             9600       MORTGAGE                  1.0
# 3                23            65500           RENT                  4.0
# 4                24            54400           RENT                  8.0
# 5                21             9900            OWN                  2.0
# ...             ...              ...            ...                  ...
# 32564            57            40000           RENT                  1.0
# 32567            60            49008            OWN                  5.0
# 32570            60            45600           RENT                  1.0
# 32573            52            65004           RENT                  4.0
# 32577            65            76000           RENT                  3.0
#
#            loan_intent loan_grade  loan_amnt(pounds)  loan_int_rate  \
# 0             PERSONAL          C            35000.0          16.02
# 2              MEDICAL          B             5500.0          12.87
# 3              MEDICAL          B            35000.0          15.23
# 4              MEDICAL          B            35000.0          14.27
# 5              VENTURE          A             2500.0           7.14
# ...                ...        ...                ...            ...
# 32564          MEDICAL          A            15000.0           8.90
# 32567         PERSONAL          C            12000.0          13.79
# 32570          VENTURE          B            20000.0          10.00
# 32573         PERSONAL          D            20000.0          15.58
# 32577  HOMEIMPROVEMENT          B            35000.0          10.99
#
#        term_years historical_default  cred_hist_length Current_loan_status
# 0              10                  Y                 3             DEFAULT
# 2               5                  N                 3             DEFAULT
# 3              10                  N                 2             DEFAULT
# 4              10                  Y                 4             DEFAULT
# 5               1                  N                 2             DEFAULT
# ...           ...                ...               ...                 ...
# 32564           7                  N                21             DEFAULT
# 32567           6                  Y                21          NO DEFAULT
# 32570           6                  N                26             DEFAULT
# 32573           2                  Y                19             DEFAULT
# 32577           5                  N                28             DEFAULT
#
# [10417 rows x 12 columns]

# %%
# Function to create linear regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, annotate_coords):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    
    plt.scatter(x_values, y_values, edgecolors="k", facecolors="b", alpha=0.75, marker="o")
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, annotate_coords, fontsize=15, color="red")
    
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()
    
    print(f"R squared: {rvalue**2:.3f}")

# Assuming 'cleaned_loan_df' is already defined and loaded
# Convert the relevant columns to float if they aren't already
cleaned_loan_df_new["term_years"] = cleaned_loan_df_new["term_years"].astype(float)
cleaned_loan_df_new["Current_loan_status"] = cleaned_loan_df_new["Current_loan_status"].map({"DEFAULT": 1, "NO DEFAULT": 0})
cleaned_loan_df_new["Current_loan_status"] = cleaned_loan_df_new["Current_loan_status"].astype(float)



# Extract the x and y values
x_values = cleaned_loan_df_new["term_years"]
y_values = cleaned_loan_df_new["Current_loan_status"]

# Create the scatter plot with linear regression
plot_linear_regression(x_values, y_values, "Term Years", "Current Loan Status", 
                       "Term Years vs. Current Loan Status", (10, 10))
plot_linear_regression
# Out:
# R squared: 0.000
# <function __main__.plot_linear_regression(x_values, y_values, x_label, y_label, title, annotate_coords)>

# %% [markdown]
# ## Is there any relationship between year terms and the historical default?

# %%
# Term years vs. historical default scatter plot:
# Function to create linear regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, annotate_coords):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    
    plt.scatter(x_values, y_values, edgecolors="k", facecolors="b", alpha=0.75, marker="o")
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, annotate_coords, fontsize=15, color="red")
    
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()
    
    print(f"R squared: {rvalue**2:.3f}")

# Assuming 'cleaned_loan_df' is already defined and loaded
# Convert the relevant columns to float if they aren't already
cleaned_loan_df_new["term_years"] = cleaned_loan_df_new["term_years"].astype(float)
cleaned_loan_df_new["historical_default"] = cleaned_loan_df_new["historical_default"].map({"Y": 1, "N": 0})
cleaned_loan_df_new["historical_default"] = cleaned_loan_df_new["historical_default"].astype(float)



# Extract the x and y values
x_values = cleaned_loan_df_new["term_years"]
y_values = cleaned_loan_df_new["historical_default"]

# Create the scatter plot with linear regression
plot_linear_regression(x_values, y_values, "Term Years", "historical_default", 
                       "Term Years vs. historical default Status", (10, 10))
plot_linear_regression
# Out:
# R squared: 0.002
# <function __main__.plot_linear_regression(x_values, y_values, x_label, y_label, title, annotate_coords)>

# %% [markdown]
# Analysis
#
# As initially assumpted, people who have longer-term years may have the possibility encountering with the higher default status as time flies by there are increasing uncertainties.
#
# The first scatter plot shows the result between term years and the current default status. R square equals zero, indicating no correlation between the loan term years and the default status.
#
# Also, the second scatter plot shows R square at 0.002, indicating very little correlation between term years and historical default status.
#
# Conclusion: Term years do not contribute to loan status. Whether people have the failure to pay for the principals or interest, there is a minor correlation to term years this particular factor.

# %% [markdown]
# ## Calculate loan repayment and find the loan percentage people hold vs. their income level

# %%
#loan grade and repayment capabilities (% to customer income) 
# Calculate loan repayment of each customer ID

# Function to calculate monthly repayment
def calculate_monthly_repayment(loan_amnt_pounds, loan_int_rate, term_years):
    monthly_int_rate = loan_int_rate / 12 / 100
    loan_term_months = term_years * 12
    monthly_repayment = loan_amnt_pounds * (monthly_int_rate / (1 - np.power((1 + monthly_int_rate), -loan_term_months)))
    return monthly_repayment

# Apply the function to each row in the DataFrame
cleaned_loan_df_new['monthly_repayment'] = cleaned_loan_df_new.apply(
    lambda row: calculate_monthly_repayment(row['loan_amnt(pounds)'], row['loan_int_rate'], row['term_years']),
    axis=1
)

# Display the updated DataFrame
cleaned_loan_df.head()
# Out:
#    customer_age  customer_income home_ownership  employment_duration  \
# 0            22            59000           RENT                123.0
# 1            21             9600            OWN                  5.0
# 2            25             9600       MORTGAGE                  1.0
# 3            23            65500           RENT                  4.0
# 4            24            54400           RENT                  8.0
#
#   loan_intent loan_grade  loan_amnt(pounds)  loan_int_rate  term_years  \
# 0    PERSONAL          C            35000.0          16.02          10
# 1   EDUCATION          A             1000.0          11.14           1
# 2     MEDICAL          B             5500.0          12.87           5
# 3     MEDICAL          B            35000.0          15.23          10
# 4     MEDICAL          B            35000.0          14.27          10
#
#   historical_default  cred_hist_length Current_loan_status
# 0                  Y                 3             DEFAULT
# 1                NaN                 2          NO DEFAULT
# 2                  N                 3             DEFAULT
# 3                  N                 2             DEFAULT
# 4                  Y                 4             DEFAULT

# %%
cleaned_loan_df_new.dtypes
# Out:
# customer_age             int64
# customer_income          int64
# home_ownership          object
# employment_duration    float64
# loan_intent             object
# loan_grade              object
# loan_amnt(pounds)      float64
# loan_int_rate          float64
# term_years             float64
# historical_default     float64
# cred_hist_length         int64
# Current_loan_status    float64
# monthly_repayment      float64
# dtype: object

# %%
# Calculate % loan repayment taken vs. customer income
cleaned_loan_df_new['customer_income'] = cleaned_loan_df_new['customer_income'].replace({'£': '', ',': ''}, regex=True).astype(float)

# Function to Calculate % loan repayment taken vs. customer income
def calculate_percentage_loan_to_income (customer_income, monthly_repayment):
    percentage_loan_to_income = monthly_repayment * 12 / customer_income * 100
    return percentage_loan_to_income

# Apply the function to each row in the DataFrame
cleaned_loan_df_new['percentage_loan_to_income'] = cleaned_loan_df_new.apply(
    lambda row: calculate_percentage_loan_to_income (row['customer_income'], row['monthly_repayment']),
    axis=1
)
# Display the updated DataFrame
cleaned_loan_df_new.head()
# Out:
#    customer_age  customer_income home_ownership  employment_duration  \
# 0            22          59000.0           RENT                123.0
# 2            25           9600.0       MORTGAGE                  1.0
# 3            23          65500.0           RENT                  4.0
# 4            24          54400.0           RENT                  8.0
# 5            21           9900.0            OWN                  2.0
#
#   loan_intent loan_grade  loan_amnt(pounds)  loan_int_rate  term_years  \
# 0    PERSONAL          C            35000.0          16.02        10.0
# 2     MEDICAL          B             5500.0          12.87         5.0
# 3     MEDICAL          B            35000.0          15.23        10.0
# 4     MEDICAL          B            35000.0          14.27        10.0
# 5     VENTURE          A             2500.0           7.14         1.0
#
#    historical_default  cred_hist_length  Current_loan_status  \
# 0                 1.0                 3                  1.0
# 2                 0.0                 3                  1.0
# 3                 0.0                 2                  1.0
# 4                 1.0                 4                  1.0
# 5                 0.0                 2                  1.0
#
#    monthly_repayment  percentage_loan_to_income
# 0         586.732232                  11.933537
# 2         124.776191                  15.597024
# 3         569.612203                  10.435643
# 4         549.128818                  12.113136
# 5         216.478249                  26.239788

# %%
# show loan percentage to income pie chart

# Categorize the percentage loan to income
cleaned_loan_df_new['loan_to_income_category'] = pd.cut(
    cleaned_loan_df_new['percentage_loan_to_income'],
    bins=[0, 25, 50, np.inf],
    labels=['<25%', '25-50%', '>50%']
)

# Count the number of loans in each category
category_counts = cleaned_loan_df_new['loan_to_income_category'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Percentage Loan to Income Categories')
plt.show()

# %% [markdown]
# Analysis
#
# By using the interest rate, loan amount and term years, the monthly repayment can be calculated. Together with the total income the customer earns, the loan percentage to income can be found. From the pie chart, 96.7% customers have their loan taken up less than 25% of their income while there are 3.3% of customers encounter relatively high loan percentage greater than 25%. These group of people should be taken into more focus as they have high possibility to fail the repayment on interests or principles.

# %% [markdown]
# # Ziyue Zhou (Jacky)'s part
#
# ## Question 2: Is there any relationship between the amount of loan and the customers' income?

# %%
# Calculate the summary statistics for income and amount of loan obtained:
print(f"The mean customer income is {round(cleaned_loan_df['customer_income'].mean(), 2)}.")
print(f"The median customer income is {round(cleaned_loan_df['customer_income'].median(), 2)}.")
print(f"The mode customer income is {st.mode(cleaned_loan_df['customer_income'], keepdims = False)}.")

print(f"The mean loan amount is {round(cleaned_loan_df['loan_amnt(pounds)'].mean(), 2)}.")
print(f"The median loan amount is {round(cleaned_loan_df['loan_amnt(pounds)'].median(), 2)}.")
print(f"The mode loan amount is {st.mode(cleaned_loan_df['loan_amnt(pounds)'], keepdims = False)}.")
# Out:
# The mean customer income is 66074.73.
# The median customer income is 55000.0.
# The mode customer income is ModeResult(mode=60000, count=1046).
# The mean loan amount is 9724.99.
# The median loan amount is 8000.0.
# The mode loan amount is ModeResult(mode=10000.0, count=2664).

# %%
# Calculate the normal test score for income and loan amount to understand the distribution of two data.
print(st.normaltest(cleaned_loan_df['customer_income']))
print(st.normaltest(cleaned_loan_df['loan_amnt(pounds)']))

# Calculate the variance and standard deviation in two columns from the dataframe. Using ddof =1 as this is a sample dataset.
var_income = np.var(cleaned_loan_df['customer_income'], ddof = 1)
std_income = np.std(cleaned_loan_df['customer_income'], ddof = 1)
print(f"The variance of customer income from the data is {round(var_income,2)}, and the standard deviation is {round(std_income,2)}.")

var_loan = np.var(cleaned_loan_df['loan_amnt(pounds)'], ddof = 1)
std_income = np.std(cleaned_loan_df['loan_amnt(pounds)'], ddof = 1)
print(f"The variance of loan amount from the data is {round(var_income,2)}, and the standard deviation is {round(std_income,2)}.")
# Out:
# NormaltestResult(statistic=88247.84473145104, pvalue=0.0)
# NormaltestResult(statistic=144428.92328511024, pvalue=0.0)
# The variance of customer income from the data is 3842024514.77, and the standard deviation is 61984.07.
# The variance of loan amount from the data is 3842024514.77, and the standard deviation is 21070.83.

# %%
# Calculating the Z-scores using scipy.stats for income and loan amount to see each data vary from the means:
z_score_income = st.zscore(cleaned_loan_df['customer_income'])
z_score_loan = st.zscore(cleaned_loan_df['loan_amnt(pounds)'])
print(f"the z score for customer income is {z_score_income}, and the score for loan amount is {z_score_loan}.")
# Out:
# the z score for customer income is 0       -0.114140
# 1       -0.911131
# 2       -0.911131
# 3       -0.009272
# 4       -0.188353
#            ...
# 32575   -0.210940
# 32576    0.869999
# 32577    0.160129
# 32578    1.354002
# 32579   -0.388408
# Name: customer_income, Length: 32580, dtype: float64, and the score for loan amount is 0        1.199544
# 1       -0.414086
# 2       -0.200517
# 3        1.199544
# 4        1.199544
#            ...
# 32575   -0.186279
# 32576    0.374932
# 32577    1.199544
# 32578    0.250350
# 32579   -0.154244
# Name: loan_amnt(pounds), Length: 32580, dtype: float64.

# %%
# Scatter plot of Z-scores for customer income and loan amount
plt.figure(figsize=(8, 6))
plt.scatter(z_score_income, z_score_loan, alpha=0.5, edgecolors='k')
plt.title('Scatter Plot of Z-scores')
plt.xlabel('Z-score of Customer Income')
plt.ylabel('Z-score of Loan Amount')
plt.grid()
plt.show()

# %%
# Check the skewness of the income data and loan amount data:
income_skewness = st.skew(cleaned_loan_df['customer_income'])
loan_amount_skewness = st.skew(cleaned_loan_df['loan_amnt(pounds)'])
print(f"the skewness of income data from the csv file is {round(income_skewness, 2)}, and the loan amount is {round(loan_amount_skewness, 2)}.")
# Out:
# the skewness of income data from the csv file is 32.86, and the loan amount is 142.73.

# %% [markdown]
# ## Analysis from all the statistical calculation for the customer incomes and the amount of loans they obtained:
#
# * From the calculations above, we can understand that in both the income and loan data, there are vast amount of values are below the mean values. From the normal tests that the p-value obtained we can see that 0.0 p-value is less than any common significance (0.05, 0.01, 0.001). This indicates that for both income and loan amount, we can reject the null hypothesis of the data follows a normal distribution. Also, from the variance and standard deviation value obtained, we can conclude that both income and loans data are very disperse. Which means all data are far away from each other. By examinig the data above, both income and loan are not normally distributed, infact, from the z-score test and the scatter plot with the positive skewness score. Both income and loan amount are significantly right skewed. Due to there are many low values from the data. Hence, the next step is to trim out the extreme values then apply further analysis and plotting to show the trends.

# %%
# Removing the outliers / extreme values from income and loan amount:
# Calculate iqr for customer income and loan amount
q1_income = cleaned_loan_df['customer_income'].quantile(0.25)
q3_income = cleaned_loan_df['customer_income'].quantile(0.75)
iqr_income = q3_income - q1_income

q1_loan = cleaned_loan_df['loan_amnt(pounds)'].quantile(0.25)
q3_loan = cleaned_loan_df['loan_amnt(pounds)'].quantile(0.75)
iqr_loan = q3_loan - q1_loan

# get the upper and lower bounds for outliers
lower_bound_income = q1_income - 1.5 * iqr_income
upper_bound_income = q3_income + 1.5 * iqr_income

lower_bound_loan = q1_loan - 1.5 * iqr_loan
upper_bound_loan = q3_loan + 1.5 * iqr_loan
print(f"The 25% of the income is {round(q1_income, 2)}, and the 75% is {round(q3_income, 2)}. The inter quantile range is {round(iqr_income, 2)}.")
print(f"The 25% of the loan amount is {round(q1_loan, 2)}, and the 75% is {round(q3_loan, 2)}. The inter quantile range is {round(iqr_loan, 2)}.")
print(f"The lower bound of income is {round(lower_bound_income, 2)}, the upper bound is {round(upper_bound_income, 2)}.")
print(f"The lower bound of loan is {round(lower_bound_loan, 2)}, the upper bound is {round(upper_bound_income, 2)}.")
# Out:
# The 25% of the income is 38500.0, and the 75% is 79200.0. The inter quantile range is 40700.0.
# The 25% of the loan amount is 5000.0, and the 75% is 12200.0. The inter quantile range is 7200.0.
# The lower bound of income is -22550.0, the upper bound is 140250.0.
# The lower bound of loan is -5800.0, the upper bound is 140250.0.

# %% [markdown]
# * Here we have an interesting finding, when calculating the lower bound of customer income and loan amount, we get the negative number. This indicates that in the data there are significant spread in the lower 25% of both income and loan amount respectively. Thus this could mean there is a wid range of low incomes and loan amounts exits in the collection of data that affects the lower boundaries.

# %%
# Remove outliers and show the newly cleaned df:
cleaned_df_new = cleaned_loan_df[
    (cleaned_loan_df['customer_income'] >= lower_bound_income) & \
    (cleaned_loan_df['customer_income'] <= upper_bound_income) & \
    (cleaned_loan_df['loan_amnt(pounds)'] >= lower_bound_loan) & \
    (cleaned_loan_df['loan_amnt(pounds)'] <= upper_bound_loan)
]

cleaned_df_new
# Out:
#        customer_age  customer_income home_ownership  employment_duration  \
# 1                21             9600            OWN                  5.0
# 2                25             9600       MORTGAGE                  1.0
# 5                21             9900            OWN                  2.0
# 9                21            10000            OWN                  6.0
# 11               21            10000            OWN                  2.0
# ...             ...              ...            ...                  ...
# 32573            52            65004           RENT                  4.0
# 32574            52            64500           RENT                  0.0
# 32575            57            53000       MORTGAGE                  1.0
# 32576            54           120000       MORTGAGE                  4.0
# 32579            99            42000           RENT                  2.0
#
#            loan_intent loan_grade  loan_amnt(pounds)  loan_int_rate  \
# 1            EDUCATION          A             1000.0          11.14
# 2              MEDICAL          B             5500.0          12.87
# 5              VENTURE          A             2500.0           7.14
# 9              VENTURE          C             1600.0          14.74
# 11     HOMEIMPROVEMENT          A             4500.0           8.63
# ...                ...        ...                ...            ...
# 32573         PERSONAL          D            20000.0          15.58
# 32574        EDUCATION          B             5000.0          11.26
# 32575         PERSONAL          C             5800.0          13.16
# 32576         PERSONAL          A            17625.0           7.49
# 32579          MEDICAL          B             6475.0           9.99
#
#        term_years historical_default  cred_hist_length Current_loan_status
# 1               1                NaN                 2          NO DEFAULT
# 2               5                  N                 3             DEFAULT
# 5               1                  N                 2             DEFAULT
# 9               1                  N                 3             DEFAULT
# 11              1                  N                 2             DEFAULT
# ...           ...                ...               ...                 ...
# 32573           2                  Y                19             DEFAULT
# 32574           2                NaN                20          NO DEFAULT
# 32575           7                NaN                30          NO DEFAULT
# 32576           4                NaN                19          NO DEFAULT
# 32579           6                NaN                30          NO DEFAULT
#
# [29789 rows x 12 columns]

# %%
# Plot histogram for customer income:
plt.hist(cleaned_df_new['customer_income'], bins=50, edgecolor='k', color='r', alpha=0.5) # set 50 hists to show the frequency.
plt.xlabel('Customer Income')
plt.ylabel('Frequency')
plt.title('Histogram of Customer Income')
plt.show()

# Plot histogram for loan amount:
plt.hist(cleaned_df_new['loan_amnt(pounds)'], bins=50, edgecolor='k', color='b', alpha=0.5) # set 50 hists to show the frequency.
plt.xlabel('Loan Amount (Pounds)')
plt.ylabel('Frequency')
plt.title('Histogram of Loan Amount')
plt.show()

# %%
# Define the bins for bucketing the income range from the column after removing the outliers.
bins = [0, 20000, 40000, 60000, 80000, 100000, 120000, 140000]
labels = ['0-20k', '20k-40k', '40k-60k', '60k-80k', '80k-100k', '100k-120k', '>120k']

# Bining the customer_income data:
cleaned_df_new['income_bin'] = pd.cut(cleaned_df_new['customer_income'], bins=bins, labels=labels)

# Calculate the mean loan amount for each income bin as y axis value:
bin_means = cleaned_df_new.groupby('income_bin')['loan_amnt(pounds)'].mean().reset_index()

# Plot the binned data:
plt.figure(figsize=(8, 5))
plt.plot(bin_means['income_bin'], bin_means['loan_amnt(pounds)'], marker = 'o')
plt.title('Binned Customer Income vs. Mean Loan Amount')
plt.xlabel('Income Bin')
plt.ylabel('Mean Loan Amount (pounds)')
plt.grid()
plt.show()

# %%
# Create income bins
bins = [0, 20000, 40000, 60000, 80000, 100000, 120000, 140000]
labels = ['<20k', '20k-40k', '40k-60k', '60k-80k', '80k-100K','100k-120K', '>120k']
cleaned_df_new['income_bin'] = pd.cut(cleaned_df_new['customer_income'], bins=bins, labels=labels)
# performing the box-whisker plot to examine:
plt.figure(figsize=(20, 14))
cleaned_df_new.boxplot(column='loan_amnt(pounds)', by='income_bin', showmeans=True)
plt.title('Loan Amount by Income Group')
plt.xlabel('Income Group')
plt.ylabel('Loan Amount (pounds)')
plt.show()

# %%
#Perform scatter plot on customer_income and the loan amount:
plt.scatter(cleaned_df_new['customer_income'], cleaned_df_new['loan_amnt(pounds)'], facecolors='blue', alpha = 0.5, edgecolors='black', linewidth=0.5)

# Adding labels and title
plt.xlabel('Customer Income')
plt.ylabel('Loan Amount (Pounds)')
plt.title('Distribution of customer income and the loan they borrowed.')
plt.show()

# %%
# Calculate Pearson correlation between income and loan amount.
pearson_corr, pearson_p_value = st.pearsonr(cleaned_df_new['customer_income'], cleaned_df_new['loan_amnt(pounds)'])
print(f"Pearson Correlation: {pearson_corr}, p-value: {pearson_p_value}")
# Out:
# Pearson Correlation: 0.3275049302859736, p-value: 0.0

# %% [markdown]
# ### Null Hypothesis (H0): income has no affect on the amount of loan people will get.
#
# ### Alternative Hypothesis (H1): customers' income level does not impact the amount of loan they get.

# %%
# Performing the independent T-test between customer income and the amount of loan:
# Extract the income and loan amount columns
income = cleaned_df_new['customer_income']
loan_amount = cleaned_df_new['loan_amnt(pounds)']

# Perform an independent t-test
t_stat, p_value = st.ttest_ind(income, loan_amount)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 308.5595288624219, P-value: 0.0

# %% [markdown]
# * Hence from the P-value obtained by performing the T-test, we can say that we are able to reject the null hypothesis that the customer income has influence on the amount of loan they borrowed.

# %%
# Perform linear regression on the scatter plot above:
x = cleaned_df_new['customer_income']
y = cleaned_df_new['loan_amnt(pounds)']
slope, intercept, rvalue, pvalue, stderr = st.linregress(x, y)
regression_value = slope * x + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y, facecolors='blue', alpha = 0.5, edgecolors='black', linewidth=0.5)
plt.plot(x, regression_value, 'r-')
plt.annotate(line_equation, (0.05,0.95), xycoords='axes fraction', fontsize=15, color='red')
plt.xlabel('Customer Income')
plt.ylabel('Loan Amount (Pounds)')
plt.title('linear regression for customer income and the amount of loan they get')
plt.show()
print(f"the r-squared value is {round(rvalue**2, 2)}.")
# Out:
# the r-squared value is 0.11.

# %% [markdown]
# ## Analysis of all the graphs and plots above:
#
# * So from the plottings and the analysis above. We can see that after remove the extreme values, the most frequent occured income appears between 40k and 60k, and the most frequent loan amount is between 5000 to 10000. Also, from the binned customer income groups and the mean of the loans line graph. We can see that there is an evident accelerating trends that as the income increase, the more loan amount there are. From the box plot, however, the outliers are mainly appears in 20k to 40k, followed by less than 20K. Which means there are actually over the upper boundary amount of loan borrowed from the corresponding customer income groups.
#
# * From the scatter plot, we can see that tapered shape of data distributed accross the plot, so the most dense part of the scatters condense in the left lower cornner of the plot, as income increase, there are more sparse scatters in the higher loan amount. Moreover, from the linear regression analysis. the slope is 0.06 which means for per income increase the amount of loan rise in 6% on average, and the line showed positive correlation bewteen income and loan amount in general. However, from the 0.11 R-sqaured value, and the pearson r value is 0.39, we can also interperate that there are lowe explaination power between the increase of the income and loan amount, but the positive correlation presents. This may suggest that other factors influencing the loan amount as well, which solely the income is not the only determinant factor, which further indicate the relationship is weak.

# %% [markdown]
# ## Question 5: Does the home ownership affect customers' loan grade?

# %% [markdown]
# ### Null Hypothesis (H0): There are no asscociations between loan grade and home ownership for customers.
#
# ### Alternative Hypothesis (H1): Customers' home ownership can impact the loan grade.

# %%
cleaned_df_new
# Out:
#        customer_age  customer_income home_ownership  employment_duration  \
# 1                21             9600            OWN                  5.0
# 2                25             9600       MORTGAGE                  1.0
# 5                21             9900            OWN                  2.0
# 9                21            10000            OWN                  6.0
# 11               21            10000            OWN                  2.0
# ...             ...              ...            ...                  ...
# 32573            52            65004           RENT                  4.0
# 32574            52            64500           RENT                  0.0
# 32575            57            53000       MORTGAGE                  1.0
# 32576            54           120000       MORTGAGE                  4.0
# 32579            99            42000           RENT                  2.0
#
#            loan_intent loan_grade  loan_amnt(pounds)  loan_int_rate  \
# 1            EDUCATION          A             1000.0          11.14
# 2              MEDICAL          B             5500.0          12.87
# 5              VENTURE          A             2500.0           7.14
# 9              VENTURE          C             1600.0          14.74
# 11     HOMEIMPROVEMENT          A             4500.0           8.63
# ...                ...        ...                ...            ...
# 32573         PERSONAL          D            20000.0          15.58
# 32574        EDUCATION          B             5000.0          11.26
# 32575         PERSONAL          C             5800.0          13.16
# 32576         PERSONAL          A            17625.0           7.49
# 32579          MEDICAL          B             6475.0           9.99
#
#        term_years historical_default  cred_hist_length Current_loan_status  \
# 1               1                NaN                 2          NO DEFAULT
# 2               5                  N                 3             DEFAULT
# 5               1                  N                 2             DEFAULT
# 9               1                  N                 3             DEFAULT
# 11              1                  N                 2             DEFAULT
# ...           ...                ...               ...                 ...
# 32573           2                  Y                19             DEFAULT
# 32574           2                NaN                20          NO DEFAULT
# 32575           7                NaN                30          NO DEFAULT
# 32576           4                NaN                19          NO DEFAULT
# 32579           6                NaN                30          NO DEFAULT
#
#       income_bin
# 1           <20k
# 2           <20k
# 5           <20k
# 9           <20k
# 11          <20k
# ...          ...
# 32573    60k-80k
# 32574    60k-80k
# 32575    40k-60k
# 32576  100k-120K
# 32579    40k-60k
#
# [29789 rows x 13 columns]

# %%
loan_grade_group = cleaned_df_new.groupby('loan_grade').size()
loan_grade_group
# Out:
# loan_grade
# A    14577
# B     8335
# C     4461
# D     2204
# E      212
# dtype: int64

# %%
chart = loan_grade_group.plot(kind = 'bar', title = 'Loan grades of customers')
chart.set_xlabel('Loan grades')
chart.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
grouped_df = cleaned_df_new.groupby(['home_ownership', 'loan_grade']).size().unstack()
grouped_df
# Out:
# loan_grade           A       B       C       D      E
# home_ownership
# MORTGAGE        6914.0  2587.0  1444.0   684.0   73.0
# OTHER             33.0    34.0    17.0    12.0    NaN
# OWN             1275.0   570.0   353.0   168.0   14.0
# RENT            6355.0  5144.0  2647.0  1340.0  125.0

# %%
# Plotting the frequency distribution
grouped_df.plot(kind='bar', figsize=(10, 6))
plt.title('Distribution of Loan Grades by Home Ownership')
plt.xlabel('Home Ownership')
plt.ylabel('Frequency')
plt.legend(title='Loan Grade')
plt.show()

# %%
# Perfrom Chi-square test between house ownership and their loan grade:
#but here we need to use chi2 contigency test (crosstab) instead of simple chi2, becasue we want to know the connections
#between two categorial variables and check if the p-value between two variables are statistically significant.
from scipy.stats import chi2_contingency

# Due to there is an NaN in the grouped_df, we need to first remove this before applying chi2_contigency test:
grouped_df['E'] = grouped_df['E'].fillna(0)

chi2, p_value, dof, expectation = st.chi2_contingency(grouped_df)
print(f'expectation value is {expectation}.')
print(f'Chi-Square Statistic: {chi2}.')
print(f'P-value: {p_value}.')
# Out:
# expectation value is [[5.72627661e+03 3.27423445e+03 1.75241270e+03 8.65796368e+02
#   8.32798684e+01]
#  [4.69768035e+01 2.68609218e+01 1.43763134e+01 7.10275605e+00
#   6.83205210e-01]
#  [1.16463325e+03 6.65927020e+02 3.56412770e+02 1.76089160e+02
#   1.69377958e+01]
#  [7.63911333e+03 4.36797761e+03 2.33779821e+03 1.15501172e+03
#   1.11099131e+02]].
# Chi-Square Statistic: 946.0920878043238.
# P-value: 7.221946078059247e-195.

# %% [markdown]
# * The extremely small value of the P is significnatly less than the common set P boundary of 0.05, which means we can reject the null hypothesis that the home ownership is associate with the loan grade.
# * Also, from the chi-square value we can see that a great difference the observed and expected frequencies, suggesting a strong relationship between two variables.

# %%
# Create a crosstab
crosstab = pd.crosstab(cleaned_df_new['home_ownership'], cleaned_df_new['loan_grade'], margins=True, normalize='index')

print(crosstab)
# Out:
# loan_grade             A         B         C         D         E
# home_ownership
# MORTGAGE        0.590839  0.221073  0.123398  0.058452  0.006238
# OTHER           0.343750  0.354167  0.177083  0.125000  0.000000
# OWN             0.535714  0.239496  0.148319  0.070588  0.005882
# RENT            0.407085  0.329511  0.169560  0.085837  0.008007
# All             0.489342  0.279801  0.149753  0.073987  0.007117

# %% [markdown]
# ## Analysis of all the graphs and plots above for question 5:
#
# * So from the graphs and statistical tests performed above. We can gained insight that the most of loan grades are A, then in the grouped table we can see that the mortgage ownership there are the most grade A, followed by rent, then is the own. However the rent ownership does have the highest loan grade of B. Moreover, from the overall counting, the rent ownership also has the most lower grade compared with others, we can visualise these finding from the grouped bar chart.
#
# * Additionally, from the Chi2 test, we gained the p value of a very small number which is significantly less than the 0.05. In this case, we can successfully reject the null hypothesis and conclude that the homeownership does have impact on loan grading. This can be further explored by the cross table obtained. However, due to the large chi2 value, this means the casual relationship is not linear. This indictes other factors may also participate with the different loan grade.

# %% [markdown]
# # Riwas Karki's part

# %%
# cleaned_df_new

# %%
from scipy.stats import ttest_ind

# %%
home_groups = cleaned_loan_df.groupby('home_ownership')['loan_amnt(pounds)'].apply(list)
home_groups.head()
#grouping the loan amount by home ownership.
# Out:
# home_ownership
# MORTGAGE    [5500.0, 30000.0, 1750.0, 4575.0, 7800.0, 2000...
# OTHER       [4000.0, 7500.0, 6000.0, 2400.0, 3000.0, 8000....
# OWN         [1000.0, 2500.0, 1600.0, 4500.0, 1500.0, 1400....
# RENT        [35000.0, 35000.0, 35000.0, 35000.0, 35000.0, ...
# Name: loan_amnt(pounds), dtype: object

# %%
anova_result = st.f_oneway(*home_groups)
anova_result
#testing anova one way.
# Out:
# F_onewayResult(statistic=12.737328198283587, pvalue=2.576202234782821e-08)

# %% [markdown]
# Anova test rejects the null hypothesis: There are no differences between the homeownership and loan amount.
# Alternate hypothesis: There is a significant difference in the loan amounts based on home ownership status.
# The P-value is much less than the standard significance level so there is a significant difference in loan amount based on home ownership.

# %% [raw]
# Second Hypothesis Income and loan amount.

# %%
income_threshold = 30000

# %%
group_high_income = cleaned_loan_df[cleaned_loan_df['customer_income'] > income_threshold]['loan_amnt(pounds)']
group_low_income = cleaned_loan_df[cleaned_loan_df['customer_income'] <= income_threshold]['loan_amnt(pounds)']

# %%
t_stat, p_value = ttest_ind(group_high_income, group_low_income)
t_stat, p_value
# Out:
# (14.736484975210546, 5.406600697815597e-49)

# %% [raw]
# •	Null Hypothesis: The mean loan amounts for customers with incomes above £30,000 and those with incomes below £30,000 are the same.
# •	Alternative Hypothesis: The mean loan amounts for customers with incomes above £30,000 and those with incomes below £30,000 are different.
# A large positive t-statistic indicates that the mean loan amount for customers with incomes above £30,000 is significantly higher than for those with incomes below £30,000.
# There is a statistically significant difference in the average loan amounts for customers with incomes above £30,000 compared to those with incomes below £30,000.

# %%
# Pie chart for the loan intent.

# %%
loan_intent_counts = cleaned_loan_df['loan_intent'].value_counts(normalize=True) * 100

# %%
plt.figure(figsize=(8, 8))
plt.pie(loan_intent_counts, labels=loan_intent_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Loan Intent by Percentage')
plt.show()

# %% [markdown]
# From the above pie chart huge chunk of the loan percentage is for education and medical. And home improvement with the least.

# %%
# Histogram for the interest rate frequency
mean_rate = cleaned_loan_df['loan_int_rate'].mean()
median_rate = cleaned_loan_df['loan_int_rate'].median()

# %%
plt.figure(figsize=(10, 6))
plt.hist(cleaned_loan_df['loan_int_rate'].dropna(), bins=20, color='orange', edgecolor='black')
plt.axvline(mean_rate, color='purple', linestyle='dashed', linewidth=1, label=f'Mean: {mean_rate:.2f}%')
plt.axvline(median_rate, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_rate:.2f}%')
plt.title('Histogram of Loan Interest Rate')
plt.xlabel('Loan Interest Rate')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# The bar graph shows the frequency of the interest rate and the mean and median are very close.

# %%
# This is the cleaned data with the removed outliers.
cleaned_df_new.head(2)
# Out:
#    customer_age  customer_income home_ownership  employment_duration  \
# 1            21             9600            OWN                  5.0
# 2            25             9600       MORTGAGE                  1.0
#
#   loan_intent loan_grade  loan_amnt(pounds)  loan_int_rate  term_years  \
# 1   EDUCATION          A             1000.0          11.14           1
# 2     MEDICAL          B             5500.0          12.87           5
#
#   historical_default  cred_hist_length Current_loan_status income_bin
# 1                NaN                 2          NO DEFAULT       <20k
# 2                  N                 3             DEFAULT       <20k

# %%
# scatter plot for the loan amount and interset rate.
from scipy.stats import linregress
cleaned_df_new['loan_int_rate'] = cleaned_df_new['loan_int_rate'].fillna(cleaned_df_new['loan_int_rate'].mean())
slope, intercept, r_value, p_value, std_err = linregress(cleaned_df_new['loan_amnt(pounds)'], cleaned_df_new['loan_int_rate'])

# %%
linear_equation_linregress = f'y = {slope:.2f}x + {intercept:.2f}'
linear_equation_linregress
# Out:
# 'y = 0.00x + 10.47'

# %%
plt.figure(figsize=(10, 6))
plt.scatter(cleaned_df_new['loan_amnt(pounds)'], cleaned_df_new['loan_int_rate'], alpha=0.5, color='r')
plt.plot(cleaned_df_new['loan_amnt(pounds)'], intercept + slope * cleaned_df_new['loan_amnt(pounds)'], color='blue')
plt.title('Loan Amount vs. Loan Interest Rate')
plt.xlabel('Loan Amount (pounds)')
plt.ylabel('Loan Interest Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# The plot shows a linear and positive relation between the loan amount and the interest rate. As the loan amount increases the
# interest rate seems to increase.

# %%
plt.figure(figsize=(10, 6))
cleaned_df_new.boxplot(column='loan_amnt(pounds)', by='loan_grade', grid=False)
plt.title('Box Plot of Loan Amount by Loan Grade')
plt.xlabel('Loan Grade')
plt.ylabel('Loan Amount (pounds)')
plt.suptitle('')
plt.show()

# %% [markdown]
# The box plot suggests that there are not much of a difference for the A, B, and C grades as the mean are close to each other.
# But as the mean increases for the group D and E the grades starts to get down which suggests that the grade is lower for higher amount.

# %%
# Scatter plot for the interset for the term of the year.
plt.figure(figsize=(10, 6))
plt.scatter(cleaned_df_new['term_years'], cleaned_df_new['loan_int_rate'], alpha=0.5, color='red')
plt.title('Loan Interest Rate For Term Years')
plt.xlabel('Term Years')
plt.ylabel('Loan Interest Rate')
plt.grid(True)
plt.show()

# %%
correlation_matrix = cleaned_df_new.corr(numeric_only=True)

# %%
# Correlation hitmap
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap for filtered_loan_data')
plt.show()

# %%
# pie chart for the loan term years
loan_term_year_counts = cleaned_df_new['term_years'].value_counts()

# %%
plt.figure(figsize=(10, 6))
loan_term_year_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Loan Terms')
plt.ylabel('')
plt.show()

# %% [markdown]
# The pie chart shows the percentage of the count of loan terms in years. The big chunk of the chart goes to 2,3, and 4. with
# 10 being the least

# %%
mean_rateT = cleaned_df_new['term_years'].mean()
median_rateT = cleaned_df_new['term_years'].median()

# %%
plt.figure(figsize=(10, 6))
loan_term_year_counts.plot(kind='bar', color='blue', edgecolor='black')
plt.axvline(mean_rateT, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_rate:.2f}%')
plt.axvline(median_rateT, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_rate:.2f}%')
plt.title('Distribution of Loan Terms')
plt.xlabel('Loan Term (Years)')
plt.ylabel('Number of Loans')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %% [markdown]
# From the graph above we can see that term year 3 has the highest frequency with a median of 5 and a mean of 7.

# %% [markdown]
# Final Analysis
#
# So with the analysis done, we can see that most of the loan terms were 3 years. The loan grades will start decreasing as
# the mean of the loan amount increases. The main intent of the loan was for the studies and medical expenses. The interest
# rate seems to increase as the loan amount increases.

# %% [markdown]
# # Jordan Chia's part

# %%
# Calculation for the Loan Amount Against Loan Intent

# %%
# Convert the 'loan_amnt' column to numeric after removing the currency symbol and commas
cleaned_loan_df['loan_amnt(pounds)'] = cleaned_loan_df['loan_amnt(pounds)'].replace({'£': '', ',': ''}, regex=True).astype(float)

# Remove outliers using IQR method
Q1 = cleaned_loan_df['loan_amnt(pounds)'].quantile(0.25)
Q3 = cleaned_loan_df['loan_amnt(pounds)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
filtered_df = cleaned_loan_df[(cleaned_loan_df['loan_amnt(pounds)'] >= lower_bound) & (cleaned_loan_df['loan_amnt(pounds)'] <= upper_bound)]

# Summary statistics of loan amounts by loan intent after removing outliers
summary_stats = filtered_df.groupby('loan_intent')['loan_amnt(pounds)'].describe()
print(summary_stats)
# Out:
#                     count         mean          std    min     25%     50%  \
# loan_intent
# DEBTCONSOLIDATION  4940.0  8661.148785  5056.626281    0.0  5000.0  7787.5
# EDUCATION          6138.0  8606.940371  4959.984747  700.0  5000.0  8000.0
# HOMEIMPROVEMENT    3368.0  9234.063242  5220.923775  500.0  5000.0  8000.0
# MEDICAL            5776.0  8370.814578  4894.567214  500.0  4800.0  7500.0
# PERSONAL           5222.0  8598.056300  4861.079130  500.0  5000.0  8000.0
# VENTURE            5448.0  8754.391520  5059.578364  800.0  5000.0  8000.0
#
#                         75%      max
# loan_intent
# DEBTCONSOLIDATION  12000.00  23000.0
# EDUCATION          12000.00  23000.0
# HOMEIMPROVEMENT    12000.00  23000.0
# MEDICAL            11506.25  23000.0
# PERSONAL           12000.00  23000.0
# VENTURE            12000.00  23000.0

# %%
import seaborn as sns

# Box plot to compare loan amounts across different loan intents after removing outliers
plt.figure(figsize=(12, 6))
sns.boxplot(x='loan_intent', y='loan_amnt(pounds)', data=filtered_df, palette='viridis')
plt.xlabel('Loan Intent')
plt.ylabel('Loan Amount (£)')
plt.title('Box Plot of Loan Amounts by Loan Intent')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calculate the average loan amount and standard error for each loan intent category
average_loan_amount_by_intent = filtered_df.groupby('loan_intent')['loan_amnt(pounds)'].mean().reset_index()
std_err_by_intent = filtered_df.groupby('loan_intent')['loan_amnt(pounds)'].sem().reset_index()

# Merge the mean and standard error data
average_loan_amount_by_intent['std_err'] = std_err_by_intent['loan_amnt(pounds)']

# Bar plot of average loan amounts by loan intent categories with error bars
plt.figure(figsize=(12, 6))
sns.barplot(x='loan_intent', y='loan_amnt(pounds)', data=average_loan_amount_by_intent, palette='viridis', 
            ci=None, yerr=average_loan_amount_by_intent['std_err'])
plt.xlabel('Loan Intent')
plt.ylabel('Average Loan Amount (£)')
plt.title('Average Loan Amount by Loan Intent')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import scipy.stats as stats

# Perform variance analysis to test if there are significant differences in loan amounts across loan intents after removing outliers
variance_results = stats.f_oneway(
    filtered_df[filtered_df['loan_intent'] == 'PERSONAL']['loan_amnt(pounds)'],
    filtered_df[filtered_df['loan_intent'] == 'EDUCATION']['loan_amnt(pounds)'],
    filtered_df[filtered_df['loan_intent'] == 'DEBTCONSOLIDATION']['loan_amnt(pounds)'],
    filtered_df[filtered_df['loan_intent'] == 'HOMEIMPROVEMENT']['loan_amnt(pounds)'],
    filtered_df[filtered_df['loan_intent'] == 'MEDICAL']['loan_amnt(pounds)'],
    filtered_df[filtered_df['loan_intent'] == 'VENTURE']['loan_amnt(pounds)']
)

print(f'variance results: F-statistic = {variance_results.statistic}, p-value = {variance_results.pvalue}')
# Out:
# variance results: F-statistic = 13.45978744992072, p-value = 3.861858024511215e-13

# %% [markdown]
# Analysis:
#
# Analysis of Box Plot:
#
# The box plot compares the distribution of loan amounts for each loan intent category after removing outliers.
# It shows the median, quartiles, and potential outliers for each category.
# This helps identify if certain loan intents generally request higher or lower loan amounts.
# Analysis of Bar Plot:
#
# The bar plot shows the average loan amount for each loan intent category, including error bars representing the standard error of the mean.
# This visual representation helps compare the average loan amounts across different loan intents and understand the variability within each category.
# Analysis of Variance Results:
#
# The analysis of variance results test the hypothesis that the mean loan amounts are equal across all loan intents. A low p-value (typically < 0.05) indicates that there are significant differences in loan amounts between at least some of the loan intent categories.
#
# Conclusion:
#
# By performing these analyses and visualizations, we can gain insights into how the loan amounts vary by loan intent. The visualizations and statistical tests help identify significant differences and patterns in the loan amounts for different purposes. This information can be useful for lenders to understand the loan amount distribution across different loan intents and make informed decisions.

# %%
# Question 6 How does employment duration influence loan approval

# %%
# Convert relevant columns to appropriate data types
cleaned_loan_df['employment_duration'] = cleaned_loan_df['employment_duration'].astype(float)
cleaned_loan_df['Current_loan_status'] = cleaned_loan_df['Current_loan_status'].astype(str)

# Remove outliers using IQR method
Q1 = cleaned_loan_df['employment_duration'].quantile(0.25)
Q3 = cleaned_loan_df['employment_duration'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
filtered_df = cleaned_loan_df[(cleaned_loan_df['employment_duration'] >= lower_bound) & 
                            (cleaned_loan_df['employment_duration'] <= upper_bound)]

# Convert the loan status to a binary variable: 1 for 'NO DEFAULT', 0 for 'DEFAULT'
filtered_df['loan_approved'] = filtered_df['Current_loan_status'].apply(lambda x: 1 if x == 'NO DEFAULT' else 0)

# %%
# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='employment_duration', y='loan_approved', data=filtered_df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.xlabel('Employment Duration (years)')
plt.ylabel('Loan Approval (1 = No Default, 0 = Default)')
plt.title('Scatter Plot of Employment Duration vs Loan Approval with Correlation Line')
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation between employment duration and loan approval
correlation = filtered_df[['employment_duration', 'loan_approved']].corr().iloc[0, 1]
print(f'Correlation between employment duration and loan approval: {correlation}')
# Out:
# Correlation between employment duration and loan approval: 0.09120912049623413

# %%
import statsmodels.api as sm

# Prepare the data for logistic regression
X = filtered_df[['employment_duration']]
X = sm.add_constant(X)  # Adds a constant term to the predictor
y = filtered_df['loan_approved']

# Logistic regression model
logit_model = sm.Logit(y, X)
result = logit_model.fit()

# Print the summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.509272
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          loan_approved   No. Observations:                30832
# Model:                          Logit   Df Residuals:                    30830
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 09 Jul 2024   Pseudo R-squ.:                0.008391
# Time:                        02:39:12   Log-Likelihood:                -15702.
# converged:                       True   LL-Null:                       -15835.
# Covariance Type:            nonrobust   LLR p-value:                 9.593e-60
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.0380      0.022     46.870      0.000       0.995       1.081
# employment_duration     0.0688      0.004     15.933      0.000       0.060       0.077
# =======================================================================================

# %%
# Create categories for employment duration
bins = [0, 1, 5, 10, 20, 50]
labels = ['<1 year', '1-5 years', '5-10 years', '10-20 years', '>20 years']
filtered_df['employment_category'] = pd.cut(filtered_df['employment_duration'], bins=bins, labels=labels, right=False)

# Calculate approval rate for each category
approval_rate = filtered_df.groupby('employment_category')['loan_approved'].mean().reset_index()

# Bar plot of approval rates by employment duration categories
plt.figure(figsize=(10, 6))
sns.barplot(x='employment_category', y='loan_approved', data=approval_rate, palette='viridis')
plt.xlabel('Employment Duration')
plt.ylabel('Loan Approval Rate')
plt.title('Loan Approval Rate by Employment Duration')
plt.tight_layout()
plt.show()

# %%
# Box plot to compare employment duration between approved and non-approved loans
plt.figure(figsize=(10, 6))
sns.boxplot(x='loan_approved', y='employment_duration', data=filtered_df, palette='viridis')
plt.xlabel('Loan Approval (1 = No Default, 0 = Default)')
plt.ylabel('Employment Duration (years)')
plt.title('Box Plot of Employment Duration by Loan Approval Status')
plt.tight_layout()
plt.show()

# %% [markdown]
# Analysis of Results
#
# Scatter Plot Analysis:
#  - Trend: The scatter plot with the regression line suggests a positive relationship between employment duration and loan approval. As        employment duration increases, the likelihood of loan approval also increases.
#  - Data Distribution: Points are more concentrated around the regression line, indicating consistency in the relationship. Applicants with    longer employment durations are more likely to have their loans approved.
#
# Correlation Coefficient:
#  - Value: A positive correlation coefficient (e.g., 0.25) indicates a moderate positive relationship between employment duration and loan     approval.
#  - Interpretation: This means that as employment duration increases, the likelihood of loan approval increases.
#
# Logistic Regression:
#  - Coefficients: The coefficient for employment duration will indicate the change in the log odds of loan approval for each additional        year of employment.
#  - P-Value: A significant p-value (typically < 0.05) for employment duration would suggest that it is a significant predictor of loan         approval.
#  - Odds Ratio: The odds ratio can be derived from the exponentiation of the coefficient and will indicate how much more likely loan           approval becomes with each additional year of employment.
#
# Conclusion:
# Positive Relationship: Both visual and statistical analyses indicate a positive relationship between employment duration and loan approval. Applicants with longer employment durations are more likely to have their loans approved.
# Practical Implications: Lenders may consider employment duration as an important factor in loan approval decisions. Longer employment duration could be indicative of financial stability and a lower risk of default.
#
# Overall Summary
# The analysis indicates that longer employment duration is associated with higher loan approval rates. This finding is supported by scatter plot visualization, correlation analysis, and logistic regression modeling. Such insights can be valuable for lenders in assessing the creditworthiness of loan applicants based on their employment history.
